# %% [markdown]
# # Randomized Search
#     Efficient Hyperparameter Optimization at Scale
# ## Objective
#
# This notebook introduces Randomized Search as a computationally efficient alternative to grid search. It focuses on:
#
# - When randomized search is superior to grid search
#
# - Designing probability distributions for hyperparameters
#
# - Controlling compute via n_iter
#
# - Interpreting results under stochastic search
#
# - Comparing randomized search to grid search
#
# It answers:
#
#     How do we explore large hyperparameter spaces without exploding compute cost?
#
# ## Why Randomized Search Matters
#
# Grid search:
#
# - Explodes combinatorially
#
# - Wastes effort on unimportant parameters
#
# - Scales poorly
#
# Randomized search:
#
# - Samples intelligently
#
# - Finds strong configurations faster
#
# - Scales to high-dimensional spaces
#
# Often:
#
# Randomized search finds better models in less time.
#
# ## When to Use Randomized Search
#
# - ✔ Large hyperparameter spaces
# - ✔ Continuous parameters
# - ✔ Limited compute budgets
# - ✔ Ensemble models
# - ✔ Baseline optimization
#
# - ❌ Very small grids
# - ❌ Regulatory environments requiring determinism
#
# ## Imports and dataset

# %%
import numpy as np
import pandas as pd

from scipy.stats import loguniform, randint

from sklearn.model_selection import (
    RandomizedSearchCV,
    train_test_split
)

from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer

from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score

# %%
df = pd.read_csv("D:/GitHub/Data-Science-Techniques/datasets/Supervised-classification/synthetic_credit_default_classification.csv")

X = df.drop(columns=["default", "customer_id"])
y = df["default"]

X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.3,
    stratify=y,
    random_state=2010
)

# %% [markdown]
# # MODEL
# ## Leakage-Safe Pipeline

# %%
pipeline = Pipeline(steps=[
    ("imputer", SimpleImputer(strategy="median")),
    ("scaler", StandardScaler()),
    ("model", LogisticRegression(
        max_iter=1000,
        solver="liblinear"
    ))
])

# %% [markdown]
# ## Define Parameter Distributions
#
# Unlike grid search, parameters are sampled from distributions.

# %%
param_distributions = {
    "model__C": loguniform(1e-3, 1e2),
    "model__penalty": ["l1", "l2"],
    "model__class_weight": [None, "balanced"]
}

# %% [markdown]
# Why This Works
#
# - C is sampled on a __log scale__
#
# - More focus on impactful parameters
#
# - Avoids unnecessary combinations
#
# ## – Configure RandomizedSearchCV

# %%
random_search = RandomizedSearchCV(
    estimator=pipeline,
    param_distributions=param_distributions,
    n_iter=30,
    scoring="roc_auc",
    cv=5,
    n_jobs=-1,
    random_state=42,
    verbose=1,
    return_train_score=True
)

# %% [markdown]
# `n_iter` -  directly controls compute cost.
#
# ## Fit Randomized Search

# %%
random_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# RandomizedSearchCV(cv=5,
#                    estimator=Pipeline(steps=[('imputer',
#                                               SimpleImputer(strategy='median')),
#                                              ('scaler', StandardScaler()),
#                                              ('model',
#                                               LogisticRegression(max_iter=1000,
#                                                                  solver='liblinear'))]),
#                    n_iter=30, n_jobs=-1,
#                    param_distributions={'model__C': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x000001C79D50F820>,
#                                         'model__class_weight': [None,
#                                                                 'balanced'],
#                                         'model__penalty': ['l1', 'l2']},
#                    random_state=42, return_train_score=True, scoring='roc_auc',
#                    verbose=1)

# %% [markdown]
# ## Best Parameters and Score

# %%
random_search.best_params_
# Out:
# {'model__C': np.float64(0.14445251022763064),
#  'model__class_weight': None,
#  'model__penalty': 'l1'}

# %%
random_search.best_score_
# Out:
# np.float64(0.9157140129667354)

# %% [markdown]
# ✔ Near-optimal
# ✔ Much cheaper than grid search
#
# ## Evaluate on Test Set

# %%
best_model = random_search.best_estimator_

# %%
y_test_prob = best_model.predict_proba(X_test)[:, 1]

roc_auc_score(y_test, y_test_prob)
# Out:
# np.float64(0.9138236949058834)

# %% [markdown]
# ## Analyze Search Results

# %%
results = pd.DataFrame(random_search.cv_results_)

results[
    [
        "mean_test_score",
        "mean_train_score",
        "std_test_score",
        "params"
    ]
].sort_values("mean_test_score", ascending=False)
# Out:
#     mean_test_score  mean_train_score  std_test_score  \
# 9          0.915714          0.917549        0.010570
# 0          0.915674          0.917474        0.010483
# 23         0.915622          0.917543        0.010490
# 24         0.915620          0.917553        0.010583
# 14         0.915617          0.917550        0.010614
# 27         0.915606          0.917562        0.010566
# 15         0.915604          0.917550        0.010637
# 4          0.915602          0.917560        0.010568
# 12         0.915601          0.917537        0.010616
# 1          0.915599          0.917548        0.010628
# 19         0.915595          0.917545        0.010634
# 22         0.915590          0.917537        0.010436
# 18         0.915581          0.917518        0.010484
# 25         0.915579          0.917552        0.010568
# 17         0.915579          0.917552        0.010568
# 26         0.915579          0.917552        0.010568
# 6          0.915577          0.917551        0.010571
# 10         0.915561          0.917554        0.010578
# 13         0.915469          0.917455        0.010345
# 8          0.915267          0.917190        0.010310
# 20         0.915262          0.917329        0.010260
# 28         0.915109          0.917256        0.010342
# 11         0.915064          0.917060        0.010269
# 5          0.915024          0.917219        0.010614
# 7          0.902929          0.905039        0.011519
# 2          0.891733          0.892944        0.012704
# 16         0.762172          0.766451        0.015550
# 3          0.738261          0.740269        0.007317
# 21         0.500000          0.500000        0.000000
# 29         0.500000          0.500000        0.000000
#
#                                                params
# 9   {'model__C': 0.14445251022763064, 'model__clas...
# 0   {'model__C': 0.0745934328572655, 'model__class...
# 23  {'model__C': 0.03618723330959624, 'model__clas...
# 24  {'model__C': 0.5414413211338525, 'model__class...
# 14  {'model__C': 0.9163741808778786, 'model__class...
# 27  {'model__C': 0.9761125443110458, 'model__class...
# 15  {'model__C': 1.0907475835157696, 'model__class...
# 4   {'model__C': 1.0129197956845732, 'model__class...
# 12  {'model__C': 0.19069966103000435, 'model__clas...
# 1   {'model__C': 4.5705630998014515, 'model__class...
# 19  {'model__C': 2.6373339933815254, 'model__class...
# 22  {'model__C': 0.01967432802530612, 'model__clas...
# 18  {'model__C': 0.03334792728637585, 'model__clas...
# 25  {'model__C': 70.45683638454501, 'model__class_...
# 17  {'model__C': 67.32248920775338, 'model__class_...
# 26  {'model__C': 49.830438374949125, 'model__class...
# 6   {'model__C': 14.528246637516036, 'model__class...
# 10  {'model__C': 1.1462107403425035, 'model__class...
# 13  {'model__C': 0.009962513222055111, 'model__cla...
# 8   {'model__C': 0.033205591037519584, 'model__cla...
# 20  {'model__C': 0.00407559644007287, 'model__clas...
# 28  {'model__C': 0.0027698899227562817, 'model__cl...
# 11  {'model__C': 0.028888383623653185, 'model__cla...
# 5   {'model__C': 0.001267425589893723, 'model__cla...
# 7   {'model__C': 0.008111941985431923, 'model__cla...
# 2   {'model__C': 0.006026889128682512, 'model__cla...
# 16  {'model__C': 0.0021147447960615704, 'model__cl...
# 3   {'model__C': 0.0019517224641449498, 'model__cl...
# 21  {'model__C': 0.0014857392806279248, 'model__cl...
# 29  {'model__C': 0.0016832027985721903, 'model__cl...

# %% [markdown]
# ## Bias–Variance Diagnostics

# %%
results["overfit_gap"] = (
    results["mean_train_score"] -
    results["mean_test_score"]
)

results.sort_values("overfit_gap", ascending=False).head()
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 16       0.011210      0.000511         0.005399        0.000490
# 5        0.013318      0.001328         0.006315        0.001166
# 28       0.011019      0.000623         0.005508        0.000626
# 7        0.012601      0.001018         0.006599        0.000491
# 20       0.011405      0.000489         0.006312        0.000921
#
#     param_model__C param_model__class_weight param_model__penalty  \
# 16        0.002115                  balanced                   l1
# 5         0.001267                  balanced                   l2
# 28        0.002770                      None                   l2
# 7         0.008112                      None                   l1
# 20        0.004076                      None                   l2
#
#                                                params  split0_test_score  \
# 16  {'model__C': 0.0021147447960615704, 'model__cl...           0.741803
# 5   {'model__C': 0.001267425589893723, 'model__cla...           0.925593
# 28  {'model__C': 0.0027698899227562817, 'model__cl...           0.925314
# 7   {'model__C': 0.008111941985431923, 'model__cla...           0.913832
# 20  {'model__C': 0.00407559644007287, 'model__clas...           0.925359
#
#     split1_test_score  ...  std_test_score  rank_test_score  \
# 16           0.772870  ...        0.015550               27
# 5            0.903180  ...        0.010614               24
# 28           0.903594  ...        0.010342               22
# 7            0.890663  ...        0.011519               25
# 20           0.903882  ...        0.010260               21
#
#     split0_train_score  split1_train_score  split2_train_score  \
# 16            0.732147            0.780912            0.743786
# 5             0.914722            0.920369            0.914241
# 28            0.914754            0.920354            0.914278
# 7             0.903618            0.908681            0.901488
# 20            0.914846            0.920475            0.914311
#
#     split3_train_score  split4_train_score  mean_train_score  std_train_score  \
# 16            0.772332            0.803077          0.766451         0.025595
# 5             0.916487            0.920275          0.917219         0.002642
# 28            0.916616            0.920278          0.917256         0.002618
# 7             0.903114            0.908295          0.905039         0.002905
# 20            0.916677            0.920336          0.917329         0.002632
#
#     overfit_gap
# 16     0.004279
# 5      0.002195
# 28     0.002147
# 7      0.002110
# 20     0.002067
#
# [5 rows x 24 columns]

# %% [markdown]
# ## Randomized vs Grid Search
#
# | Aspect            | Grid Search | Randomized Search |
# | ----------------- | ----------- | ----------------- |
# | Coverage          | Exhaustive  | Stochastic        |
# | Compute           | High        | Controlled        |
# | Continuous Params | Poor        | Excellent         |
# | Reproducibility   | High        | Medium            |
# | Practical Default | ❌           | ✔                 |
#
#
# ## Reproducibility Considerations

# %%
random_state=2010

# %% [markdown]
# - ✔ Fixes randomness
# - ✔ Enables comparability
# - ❌ Still non-exhaustive
#
# ## Common Mistakes (Avoided)
#
# - ❌ Using uniform distribution for log-scale parameters
# - ❌ Forgetting n_iter control
# - ❌ Tuning on test set
# - ❌ Ignoring train–validation gap
# - ❌ Oversampling weak parameters
#
# ## Key Takeaways
#
# - Randomized search is the default choice for tuning
#
# - n_iter controls cost directly
#
# - Use log-uniform for regularization
#
# - Pipelines prevent leakage
#
# - Grid search still useful for final refinement

# %% [markdown]
# ## Next Notebook
# 07_Model_Tuning_and_Optimization/
#
# └── [03_bayesian_optimization.ipynb](03_bayesian_optimization.ipynb)
