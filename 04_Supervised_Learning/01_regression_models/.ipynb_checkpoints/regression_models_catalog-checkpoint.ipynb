# %% [markdown]
# # Regression Models Catalog
#
# Folder: `01_regression_models`
#
# This notebook documents 20 popular regression models with descriptions, tuning ranges, strengths, and weaknesses.

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import mean_squared_error, r2_score

# %% [markdown]
# ## Example Data Placeholder
# Assumes `X_train, X_test, y_train, y_test` already exist.
