# %% [markdown]
# # Evaluation

# %% [markdown]
# ## Confusion Matrix - Metrics & Understanding

# %% [markdown]
#             Classification Report:
#                           precision    recall  f1-score   support
#
#                        0       0.83      0.89      0.86      1291
#                        1       0.62      0.50      0.55       467
#
#                 accuracy                           0.78      1758
#                macro avg       0.72      0.69      0.71      1758
#             weighted avg       0.77      0.78      0.78      1758
#
#             Recall (Churners): 0.5010706638115632

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
